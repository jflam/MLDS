# %% [markdown]
# # R Tools for Visual Studio 2015
#
# ### Useful info:
#
# Me: John Lam (JFLam)
# R Users for Visual Discussion Alias: (rtvsdisc)
# Download preview release: \\\\pytools\release\RTVS\Preview2
# Internal web site: http://rtvs

# %% [markdown]
# # Demo

# %% [markdown]
# #One more thing ...

# %%
options(jupyter.plot_mimetypes = 'image/png')

pairs(mtcars)

# %% [markdown]
# # Call to action
#
# - Download RTVS and kick the tires
# - Join the *rtvsdisc* alias and send us feedback
# - Interested in working on tools for Python and R, or maybe creating a new document type for Microsoft? mailto:jflam
