# %% [markdown]
# # R Tools for Visual Studio 2015
#
# #### Me: John Lam (JFLam)
# #### R Users for Visual Discussion Alias: (rtvsdisc)
# #### Download preview release: \\\\pytools\release\RTVS\Preview2
# #### Internal web site: http://rtvs

# %% [markdown]
# #One more thing ...

# %%
options(jupyter.plot_mimetypes = 'image/png')

pairs(mtcars)
